# %%
from BurdenDerek import machine_learning_summary
machine_learning_summary()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-2-05a6b72a6b1f> in <module>
#       1 from BurdenDerek import machine_learning_summary
# ----> 2 machine_learning_summary()
#
# ~\Desktop\Class\Kaggle\Academic_Sucess_Predictions\BurdenDerek.py in machine_learning_summary(show)
#      50     por_url = f"https://burdenderek-project.s3.us-east-2.amazonaws.com/{por_file}"
#      51     # save the dataframes
# ---> 52     math = extract(url=math_url, file=math_file, show=show)
#      53     por = extract(url=por_url, file=por_file, show=show)
#      54
#
# ~\Desktop\Class\Kaggle\Academic_Sucess_Predictions\BurdenDerek.py in extract(url, file, show)
#      35         spark = SparkSession.builder.appName("Project_ETL").config("spark.driver.extraClassPath","/content/postgresql-42.2.9.jar").getOrCreate()
#      36         spark.sparkContext.addFile(url)
# ...
